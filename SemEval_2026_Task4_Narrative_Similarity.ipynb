# %% [markdown]
# <a href="https://colab.research.google.com/github/AndromedaOMA/SemEval-2026_Task4-Narrative-Similarity/blob/main/SemEval_2026_Task4_Narrative_Similarity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World!")
# Out:
# Hello World!
